# %%
import pandas as pd
df=pd.read_csv('data_set_2.csv')
df.head()
# Out:
#   parent_asin        asin  rating            timestamp  \
# 0  B000000LWZ  B000000LWZ       5  1997-09-09 03:13:17
# 1  B000002H3Z  B000002H3Z       5  1997-09-13 22:05:50
# 2  B000003YSX  B000003YSX       5  1997-10-05 21:21:20
# 3  B000002H2H  B000002H2H       5  1997-10-20 14:48:57
# 4  B000002AS3  B000002AS3       5  1997-10-21 17:42:32
#
#                                                 text  main_category  price  \
# 0  It was while driving on Highway 83, heading of...  Digital Music  10.98
# 1  This isn't actually a book. It is a beautifull...  Digital Music  14.98
# 2  This album is not of what one would usually re...  Digital Music  15.99
# 3  Released on November 23 1984, Metallica's seco...  Digital Music   7.30
# 4  This is the first cd made by Oasis. My favorit...  Digital Music   9.09
#
#    log_price         domain  sentiment_score sentiment_category  year  \
# 0   2.396075  CDs_and_Vinyl         0.256641           Positive  1997
# ...

# %%
# Remove exactly 2 million random rows
if len(df) > 2000000:  # Check if we have at least 2 million rows to remove
    df.drop(df.sample(n=2000000).index, inplace=True)
    df.to_csv('data_set_3.csv', index=False)
    df2 = pd.read_csv('data_set_3.csv')
    df2.head()
else:
    print(f"Cannot remove 2 million rows. DataFrame only has {len(df)} rows.")

# %%
df2.shape
# Out:
# (2095972, 13)

# %%
    df2.head()
# Out:
#   parent_asin        asin  rating            timestamp  \
# 0  B000003YSX  B000003YSX       5  1997-10-05 21:21:20
# 1  B000002H2H  B000002H2H       5  1997-10-20 14:48:57
# 2  B000002B6Z  B000002B6Z       5  1997-11-12 01:37:58
# 3  B00000150Q  B00000150Q       5  1997-11-14 03:47:57
# 4  B000002GP1  B000002GP1       5  1997-11-18 06:54:25
#
#                                                 text  main_category  price  \
# 0  This album is not of what one would usually re...  Digital Music  15.99
# 1  Released on November 23 1984, Metallica's seco...  Digital Music   7.30
# 2  If you don't know Alice Cooper music, this is ...  Digital Music  11.95
# 3  This Cd is very well put together and has a ni...  Digital Music  14.99
# 4  &quot;Lock 'N Load&quot; is Denis Leary's seco...  Digital Music   7.77
#
#    log_price         domain  sentiment_score sentiment_category  year  \
# 0   2.771964  CDs_and_Vinyl         0.113333            Neutral  1997
# ...
